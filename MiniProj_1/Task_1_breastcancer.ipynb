# %% [markdown]
# # Setup
#
# Import the necessary packages and show the first five rows of the dataset.
#
# We already assume from the feature names that the sample code number will have nothing to do with the target and we discard this feature.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# Custom functions
def mysubplot():
    fig, ax = plt.subplots(3,3,figsize=(15,15))
    ax = ax.flatten()
    fig.delaxes(ax[-1])
    return (fig,ax)

def class_stats(df,feature,keys):
    left = df[df[feature] == 0].describe()
    right = df[df[feature] == 1].describe()
    label_list = left.index.values
    return pd.concat([left, right], keys=keys).swaplevel(0,1).sort_index().reindex(axis='index', level=0, labels=label_list)

# Make sure the dataset is correctly imported
column_names = ['Sample code number',
                'Clump Thickness',
                'Uniformity of Cell Size',
                'Uniformity of Cell Shape',
                'Marginal Adhesion',
                'Single Epithelial Cell Size',
                'Bare Nuclei',
                'Bland Chromatin',
                'Normal Nucleoli',
                'Mitoses',
                'Class']
breastcancer = pd.read_csv('breastcancer/breast-cancer-wisconsin.data',
                           names = column_names, 
                           index_col = 'Sample code number')
breastcancer.tail()
# Out:
#                     Clump Thickness  Uniformity of Cell Size  \
# Sample code number
# 776715                            3                        1
# 841769                            2                        1
# 888820                            5                       10
# 897471                            4                        8
# 897471                            4                        8
#
#                     Uniformity of Cell Shape  Marginal Adhesion  \
# Sample code number
# 776715                                     1                  1
# 841769                                     1                  1
# 888820                                    10                  3
# 897471                                     6                  4
# 897471                                     8                  5
#
#                     Single Epithelial Cell Size Bare Nuclei  Bland Chromatin  \
# Sample code number
# 776715                                        3           2                1
# 841769                                        2           1                1
# 888820                                        7           3                8
# 897471                                        3           4               10
# 897471                                        4           5               10
#
#                     Normal Nucleoli  Mitoses  Class
# Sample code number
# 776715                            1        1      2
# 841769                            1        1      2
# 888820                           10        2      4
# 897471                            6        1      4
# 897471                            4        1      4

# %% [markdown]
# ---
# # Preprocessing
#
# ## Binary Problem
#
# Convert the `Class` feature from 2 - 4 to 0 - 1 for "benign" - "malignant".

# %%
breastcancer.Class = breastcancer.Class.map(lambda Class: int(Class > 3))

breastcancer.tail()
# Out:
#                     Clump Thickness  Uniformity of Cell Size  \
# Sample code number
# 776715                            3                        1
# 841769                            2                        1
# 888820                            5                       10
# 897471                            4                        8
# 897471                            4                        8
#
#                     Uniformity of Cell Shape  Marginal Adhesion  \
# Sample code number
# 776715                                     1                  1
# 841769                                     1                  1
# 888820                                    10                  3
# 897471                                     6                  4
# 897471                                     8                  5
#
#                     Single Epithelial Cell Size Bare Nuclei  Bland Chromatin  \
# Sample code number
# 776715                                        3           2                1
# 841769                                        2           1                1
# 888820                                        7           3                8
# 897471                                        3           4               10
# 897471                                        4           5               10
#
#                     Normal Nucleoli  Mitoses  Class
# Sample code number
# 776715                            1        1      0
# 841769                            1        1      0
# 888820                           10        2      1
# 897471                            6        1      1
# 897471                            4        1      1

# %% [markdown]
# ## Problematic samples
#
# Reading the given description of the dataset, we know some samples have missing features. We choose to discard them.

# %%
breastcancer[breastcancer.eq('?').any(axis=1)]
# Out:
# C:\Users\95juj\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
#                     Clump Thickness  Uniformity of Cell Size  \
# Sample code number
# 1057013                           8                        4
# 1096800                           6                        6
# 1183246                           1                        1
# 1184840                           1                        1
# 1193683                           1                        1
# 1197510                           5                        1
# 1241232                           3                        1
# 169356                            3                        1
# 432809                            3                        1
# 563649                            8                        8
# 606140                            1                        1
# 61634                             5                        4
# 704168                            4                        6
# 733639                            3                        1
# 1238464                           1                        1
# 1057067                           1                        1
#
#                     Uniformity of Cell Shape  Marginal Adhesion  \
# Sample code number
# 1057013                                    5                  1
# 1096800                                    6                  9
# 1183246                                    1                  1
# 1184840                                    3                  1
# 1193683                                    2                  1
# 1197510                                    1                  1
# 1241232                                    4                  1
# 169356                                     1                  1
# 432809                                     3                  1
# 563649                                     8                  1
# 606140                                     1                  1
# 61634                                      3                  1
# 704168                                     5                  6
# 733639                                     1                  1
# 1238464                                    1                  1
# 1057067                                    1                  1
#
#                     Single Epithelial Cell Size Bare Nuclei  Bland Chromatin  \
# Sample code number
# 1057013                                       2           ?                7
# 1096800                                       6           ?                7
# 1183246                                       1           ?                2
# 1184840                                       2           ?                2
# 1193683                                       3           ?                1
# 1197510                                       2           ?                3
# 1241232                                       2           ?                3
# 169356                                        2           ?                3
# 432809                                        2           ?                2
# 563649                                        2           ?                6
# 606140                                        2           ?                2
# 61634                                         2           ?                2
# 704168                                        7           ?                4
# 733639                                        2           ?                3
# 1238464                                       1           ?                2
# 1057067                                       1           ?                1
#
#                     Normal Nucleoli  Mitoses  Class
# Sample code number
# 1057013                           3        1      1
# 1096800                           8        1      0
# 1183246                           1        1      0
# 1184840                           1        1      0
# 1193683                           1        1      0
# 1197510                           1        1      0
# 1241232                           1        1      0
# 169356                            1        1      0
# 432809                            1        1      0
# 563649                           10        1      1
# 606140                            1        1      0
# 61634                             3        1      0
# 704168                            9        1      0
# 733639                            1        1      0
# 1238464                           1        1      0
# 1057067                           1        1      0

# %% [markdown]
# As indicated in the description file, there are 16 samples that are missing a `Bare Nuclei` value. We eliminate those samples.

# %%
clean_breastcancer = breastcancer[breastcancer.ne('?').all(axis=1)].astype('int64')

clean_breastcancer.tail()
# Out:
#                     Clump Thickness  Uniformity of Cell Size  \
# Sample code number
# 776715                            3                        1
# 841769                            2                        1
# 888820                            5                       10
# 897471                            4                        8
# 897471                            4                        8
#
#                     Uniformity of Cell Shape  Marginal Adhesion  \
# Sample code number
# 776715                                     1                  1
# 841769                                     1                  1
# 888820                                    10                  3
# 897471                                     6                  4
# 897471                                     8                  5
#
#                     Single Epithelial Cell Size  Bare Nuclei  Bland Chromatin  \
# Sample code number
# 776715                                        3            2                1
# 841769                                        2            1                1
# 888820                                        7            3                8
# 897471                                        3            4               10
# 897471                                        4            5               10
#
#                     Normal Nucleoli  Mitoses  Class
# Sample code number
# 776715                            1        1      0
# 841769                            1        1      0
# 888820                           10        2      1
# 897471                            6        1      1
# 897471                            4        1      1

# %% [markdown]
# ## Statistics
# Compute statistics for the two classes

# %%
class_stats(clean_breastcancer,'Class',['benign','malignant'])
# Out:
#                  Clump Thickness  Uniformity of Cell Size  \
# count benign          444.000000               444.000000
#       malignant       239.000000               239.000000
# mean  benign            2.963964                 1.306306
#       malignant         7.188285                 6.577406
# std   benign            1.672661                 0.855657
#       malignant         2.437907                 2.724244
# min   benign            1.000000                 1.000000
#       malignant         1.000000                 1.000000
# 25%   benign            1.000000                 1.000000
#       malignant         5.000000                 4.000000
# 50%   benign            3.000000                 1.000000
#       malignant         8.000000                 6.000000
# 75%   benign            4.000000                 1.000000
#       malignant        10.000000                10.000000
# max   benign            8.000000                 9.000000
#       malignant        10.000000                10.000000
#
#                  Uniformity of Cell Shape  Marginal Adhesion  \
# count benign                   444.000000         444.000000
#       malignant                239.000000         239.000000
# mean  benign                     1.414414           1.346847
#       malignant                  6.560669           5.585774
# std   benign                     0.957031           0.917088
#       malignant                  2.569104           3.196631
# min   benign                     1.000000           1.000000
#       malignant                  1.000000           1.000000
# 25%   benign                     1.000000           1.000000
#       malignant                  4.000000           3.000000
# 50%   benign                     1.000000           1.000000
#       malignant                  6.000000           5.000000
# 75%   benign                     1.000000           1.000000
#       malignant                  9.000000           8.000000
# max   benign                     8.000000          10.000000
#       malignant                 10.000000          10.000000
#
#                  Single Epithelial Cell Size  Bare Nuclei  Bland Chromatin  \
# count benign                      444.000000   444.000000       444.000000
#       malignant                   239.000000   239.000000       239.000000
# mean  benign                        2.108108     1.346847         2.083333
#       malignant                     5.326360     7.627615         5.974895
# std   benign                        0.877112     1.177848         1.062299
#       malignant                     2.443087     3.116679         2.282422
# min   benign                        1.000000     1.000000         1.000000
#       malignant                     1.000000     1.000000         1.000000
# 25%   benign                        2.000000     1.000000         1.000000
#       malignant                     3.000000     5.000000         4.000000
# 50%   benign                        2.000000     1.000000         2.000000
#       malignant                     5.000000    10.000000         7.000000
# 75%   benign                        2.000000     1.000000         3.000000
#       malignant                     6.500000    10.000000         7.000000
# max   benign                       10.000000    10.000000         7.000000
#       malignant                    10.000000    10.000000        10.000000
#
#                  Normal Nucleoli     Mitoses  Class
# count benign          444.000000  444.000000  444.0
#       malignant       239.000000  239.000000  239.0
# mean  benign            1.261261    1.065315    0.0
#       malignant         5.857741    2.602510    1.0
# std   benign            0.954606    0.509738    0.0
#       malignant         3.348876    2.564495    0.0
# min   benign            1.000000    1.000000    0.0
#       malignant         1.000000    1.000000    1.0
# 25%   benign            1.000000    1.000000    0.0
#       malignant         3.000000    1.000000    1.0
# 50%   benign            1.000000    1.000000    0.0
#       malignant         6.000000    1.000000    1.0
# 75%   benign            1.000000    1.000000    0.0
#       malignant         9.500000    3.000000    1.0
# max   benign            8.000000    8.000000    0.0
#       malignant        10.000000   10.000000    1.0

# %% [markdown]
# ### Distribution plots by category
#
# In this section, we will build an intuition about the important features for separating the two classes.
# The trace is a [kernel density estimate](https://en.wikipedia.org/wiki/Kernel_density_estimation) built from the histograms.

# %%
# Histograms for good and bad wines
fig, ax = mysubplot()
for i,feature in enumerate(clean_breastcancer.columns[:-1]):
    sns.distplot(a=clean_breastcancer[clean_breastcancer.Class == 1][feature],label='malignant',ax=ax[i],kde=False)
    sns.distplot(a=clean_breastcancer[clean_breastcancer.Class == 0][feature],label='benign',ax=ax[i],kde=False)
    ax[i].legend()

# %% [markdown]
# All features have a discrete range from 1 to 10.
#
# We can already perceive that the features all features related to the `benign` tumors are ranging in low values. `Malignant` tumors are more spreaded and take values in the full range. The standard deviation attests this observation.
#
# Appart from feature `Clump Thickness`, all distribution have little overlap between the two classes, as shown by the distance between each feature mean between the two classes.

# %% [markdown]
# ## Correlation Matrix
#
# We will now center the variables and normalize them to have all variables interracting in the same range.

# %%
clean_norm_breastcancer = (clean_breastcancer - clean_breastcancer.mean())/clean_breastcancer.std()
corr = clean_norm_breastcancer.corr()
corr.iloc[-1,-1] = -1
corr.style.background_gradient(cmap='coolwarm',axis = None)
# Out:
# <style  type="text/css" >
#     #T_796a1dba_d988_11e9_8747_34f39af0e8carow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow0_col1 {
#             background-color:  #e97a5f;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow0_col2 {
#             background-color:  #e9785d;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow0_col3 {
#             background-color:  #f59c7d;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow0_col4 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow0_col5 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow0_col6 {
#             background-color:  #f18f71;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow0_col7 {
#             background-color:  #f29274;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow0_col8 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow0_col9 {
#             background-color:  #e26952;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow1_col0 {
#             background-color:  #e97a5f;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow1_col2 {
#             background-color:  #c43032;
#             color:  #f1f1f1;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow1_col3 {
#             background-color:  #e36b54;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow1_col4 {
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow1_col5 {
#             background-color:  #e46e56;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow1_col6 {
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow1_col7 {
#             background-color:  #e16751;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow1_col8 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow1_col9 {
#             background-color:  #d24b40;
#             color:  #f1f1f1;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow2_col0 {
#             background-color:  #e9785d;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow2_col1 {
#             background-color:  #c43032;
#             color:  #f1f1f1;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow2_col3 {
#             background-color:  #e57058;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow2_col4 {
#             background-color:  #e16751;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow2_col5 {
#             background-color:  #e26952;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow2_col6 {
#             background-color:  #df634e;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow2_col7 {
#             background-color:  #e26952;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow2_col8 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow2_col9 {
#             background-color:  #d24b40;
#             color:  #f1f1f1;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow3_col0 {
#             background-color:  #f59c7d;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow3_col1 {
#             background-color:  #e36b54;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow3_col2 {
#             background-color:  #e57058;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow3_col4 {
#             background-color:  #ee8468;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow3_col5 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow3_col6 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow3_col7 {
#             background-color:  #ed8366;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow3_col8 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow3_col9 {
#             background-color:  #e36b54;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow4_col0 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow4_col1 {
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow4_col2 {
#             background-color:  #e16751;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow4_col3 {
#             background-color:  #ee8468;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow4_col5 {
#             background-color:  #ef886b;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow4_col6 {
#             background-color:  #ec7f63;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow4_col7 {
#             background-color:  #eb7d62;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow4_col8 {
#             background-color:  #f59d7e;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow4_col9 {
#             background-color:  #e46e56;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow5_col0 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow5_col1 {
#             background-color:  #e46e56;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow5_col2 {
#             background-color:  #e26952;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow5_col3 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow5_col4 {
#             background-color:  #ef886b;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow5_col6 {
#             background-color:  #e57058;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow5_col7 {
#             background-color:  #ef886b;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow5_col8 {
#             background-color:  #f7b79b;
#             color:  #000000;
#         }    #T_796a1dba_d988_11e9_8747_34f39af0e8carow5_col9 {
#             background-color:  #d24b40;
#             color:  #f1f1f1;

# %% [markdown]
# We observe that several variables have some linear correlation :
#    * Cell Size, Cell Shape and the target are highly correlated, those features are redundant and one of them could be discarded.
#    * Bare Nuclei and the target.

# %% [markdown]
# # Export cleaned data

# %%
clean_breastcancer.to_csv('breastcancer/clean_breastcancer.csv')
print('done')
# Out:
# done
